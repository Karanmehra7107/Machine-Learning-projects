# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv('googleplaystore.csv')
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       1
# Android Ver       2
# dtype: int64

# %%
clean=data.dropna(subset=['Type','Android Ver','Current Ver'], inplace=True)
clean=data.isnull().sum()
clean=data

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Top Reviews App
data.sort_values('Reviews',ascending=False).iloc[0]['App']
# Out:
# 'Facebook'

# %%
# free vs paid 
data['Type'].value_counts().plot(kind='bar')

# %%
data['Type'].value_counts()
# Out:
# Free    10038
# Paid      799
# Name: Type, dtype: int64

# %%
char=data['Installs'].str.replace('+','')
char
# Out:
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10836         5,000
# 10837           100
# 10838         1,000
# 10839         1,000
# 10840    10,000,000
# Name: Installs, Length: 10837, dtype: object

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data['Installs'] = data['Installs'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else str(x))
data['Installs'] = data['Installs'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else str(x))
data['Installs'] = data['Installs'].apply(lambda x: float(x))

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
### Let's convert Price, Reviews and Ratings into Numerical Values
data['Price'] = data['Price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
data['Price'] = data['Price'].apply(lambda x: float(x))
data['Reviews'] = pd.to_numeric(data['Reviews'], errors='coerce')

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# app with largest no of installs
L_installs=data.sort_values('Installs',ascending=False)
L_installs[['App','Installs']].head()
# Out:
#                  App      Installs
# 1872  Subway Surfers  1.000000e+09
# 3816     Google News  1.000000e+09
# 3909       Instagram  1.000000e+09
# 2884   Google Photos  1.000000e+09
# 4150          Google  1.000000e+09

# %%
# app with largest size
data['Size'].value_counts()
# Out:
# Varies with device    1694
# 11M                    197
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 234k                     1
# 642k                     1
# 525k                     1
# 93k                      1
# 459k                     1
# Name: Size, Length: 461, dtype: int64

# %%
data['Size'] = data['Size'].apply(lambda x: str(x).replace('M',''))
data['Size'] = data['Size'].apply(lambda x: str(x).replace('k',''))
data['Size'] = data['Size'].apply(lambda x: str(x).replace('+',''))
data['Size'] = pd.to_numeric(data['Size'],errors='coerce')
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.sort_values('Size', ascending=False).head()
# Out:
#                             App            Category  Rating  Reviews    Size  \
# 10798      Word Search Tab 1 FR              FAMILY     0.0        0  1020.0
# 8883                      DTPay            SHOPPING     4.5       18   994.0
# 10402             FH Calculator  HEALTH_AND_FITNESS     0.0        9   992.0
# 7868            CT - DTC Lookup               TOOLS     4.1       41   986.0
# 6798   Battery Notifier BT Free               TOOLS     4.5    21979   982.0
#
#         Installs  Type  Price Content Rating            Genres  \
# 10798       50.0  Paid   1.04       Everyone            Puzzle
# 8883      1000.0  Free   0.00       Everyone          Shopping
# 10402      500.0  Free   0.00       Everyone  Health & Fitness
# 7868     10000.0  Free   0.00       Everyone             Tools
# 6798   1000000.0  Free   0.00       Everyone             Tools
#
#            Last Updated Current Ver Android Ver
# 10798  February 6, 2012         1.1  3.0 and up
# ...

# %%
# most popular category
data['Category'].value_counts().plot(kind='bar',figsize=(20,5),title='Popular category' )

# %%
# app which never udated
from datetime import datetime

# %%
data['Last Updated'].isnull().sum()
# Out:
# 0

# %%
data.drop([10472], inplace = True)

# %%
updated=data['Last Updated'] = pd.to_datetime(data['Last Updated'], format= '%B %d, %Y')
updated.sort_values(ascending=True).head(1)
# Out:
# 7479   2010-05-21
# Name: Last Updated, dtype: datetime64[ns]

# %%
updated.iloc[7479]
# Out:
# Timestamp('2018-07-03 00:00:00')
